# %% [markdown]
# # Deux exercices de tests
#
# ## Exercice 1
#
# Compléter la fonction `factorielle`

# %%
def factorielle(n):
    ...

# %% [markdown]
# ## Exercice 2
#
# Compléter la fonction fibonacci

# %%
def fibonacci(n):
    ...

# %% [markdown]
# ## Vérification
#
# Pour vérifier vos fonctions
#
# - entrer `import juge`
# - entrer `juge.test_tout()`

# %%
import juge
juge.test_tout()
